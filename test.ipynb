# %%
import datetime
import os
import logging
from typing import List, Dict, Any

import pandas as pd
from newsapi import NewsApiClient
from dotenv import load_dotenv

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("news_pipeline.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

def extract_data() -> List[Dict[str, Any]]:
    """
    Extract news articles from NewsAPI for multiple topics and combine them.
    
    Returns:
        List[Dict[str, Any]]: Combined list of articles from different topics
        
    Raises:
        NewsAPIError: If there's an issue with the NewsAPI
        EnvironmentError: If required environment variables are missing
    """
    try:
        # Get current date and date from 7 days ago
        current_date = datetime.datetime.now().strftime('%Y-%m-%d')
        logger.info(f"Current date: {current_date}")
        
        seven_days_ago = (datetime.datetime.now() - datetime.timedelta(days=7)).strftime('%Y-%m-%d')
        logger.info(f"7 days ago: {seven_days_ago}")
        
        # Load API key from .env file
        load_dotenv()
        news_api = os.getenv("NEWS_API")
        
        if not news_api:
            raise EnvironmentError("NEWS_API environment variable not found. Please check your .env file.")
        
        # Initialize NewsAPI client
        newsapi = NewsApiClient(news_api)
        
        # Define topics to search for
        topics = ['GenAI', 'AI', 'Technology']
        combined_articles = []
        
        # Fetch articles for each topic
        for topic in topics:
            logger.info(f"Fetching articles for topic: {topic}...")
            try:
                articles = newsapi.get_everything(
                    q=topic,
                    from_param=seven_days_ago,
                    to=current_date,
                    language='en',
                    sort_by='relevancy',
                    page=2
                )
                
                if 'articles' not in articles:
                    logger.warning(f"No articles found for topic: {topic}")
                    continue
                    
                logger.info(f"Fetched {len(articles['articles'])} articles for topic: {topic}")
                combined_articles.extend(articles['articles'])
                
            except Exception as e:
                logger.error(f"Error fetching articles for topic {topic}: {str(e)}")
                # Continue with other topics rather than failing completely
        
        if not combined_articles:
            raise NewsAPIError("No articles were fetched from any topic")
        
        # Remove duplicate articles (same URL)
        seen_urls = set()
        unique_articles = []
        
        for article in combined_articles:
            if article['url'] not in seen_urls:
                seen_urls.add(article['url'])
                unique_articles.append(article)
        
        logger.info(f"Total unique articles fetched: {len(unique_articles)}")
        return unique_articles
        
    except Exception as e:
        logger.error(f"Error in extract_data: {str(e)}")
        raise

# %%
extract_data()
# Out:
# 2025-04-22 17:21:47,360 - __main__ - INFO - Current date: 2025-04-22
# 2025-04-22 17:21:47,362 - __main__ - INFO - 7 days ago: 2025-04-15
# 2025-04-22 17:21:47,365 - __main__ - INFO - Fetching articles for topic: GenAI...
# 2025-04-22 17:21:47,666 - __main__ - INFO - Fetched 100 articles for topic: GenAI
# 2025-04-22 17:21:47,666 - __main__ - INFO - Fetching articles for topic: AI...
# 2025-04-22 17:21:47,961 - __main__ - INFO - Fetched 98 articles for topic: AI
# 2025-04-22 17:21:47,962 - __main__ - INFO - Fetching articles for topic: Technology...
# 2025-04-22 17:21:48,363 - __main__ - INFO - Fetched 99 articles for topic: Technology
# 2025-04-22 17:21:48,364 - __main__ - INFO - Total unique articles fetched: 291
# [{'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'michelangelo.bucci@gmail.com',
#   'title': 'gaspare 0.3.2',
#   'description': "A rewriting of Answer.AI's Gaspard to the new Genai SDK",
#   'url': 'https://pypi.org/project/gaspare/0.3.2/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-18T22:46:42Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'michelangelo.bucci@gmail.com',
#   'title': 'gaspare 0.3.1',
#   'description': "A rewriting of Answer.AI's Gaspard to the new Genai SDK",
#   'url': 'https://pypi.org/project/gaspare/0.3.1/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-18T22:28:22Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Blogs.com'},
#   'author': 'SLHamlet',
#   'title': 'Compare/Contrast: Sims 4 Speed Build vs. Meta\'s "Faster" Gen AI Tools',
#   'description': "I've asked this before, but here I go again: What's the point of prompt-based 3D building tools, when we already have many multiple 3D building tools which are user-friendly, feature-rich, and, well, fun? This point must be repeated, since Meta...",
#   'url': 'https://nwn.blogs.com/nwn/2025/04/sims-4-vs-horizon-worlds-video.html',
#   'urlToImage': 'https://nwn.blogs.com/.a/6a00d8341bf74053ef02c8d3d13d85200c-600wi',
#   'publishedAt': '2025-04-17T22:09:46Z',
#   'content': "I've asked this before, but here I go again: What's the point of prompt-based 3D building tools, when we already have many multiple 3D building tools which are user-friendly, feature-rich, and, well,… [+1019 chars]"},
#  {'source': {'id': None, 'name': 'Help Net Security'},
#   'author': 'Help Net Security',
#   'title': 'Week in review: LLM package hallucinations harm supply chains, Nagios Log Server flaws fixed',
#   'description': 'Here’s an overview of some of last week’s most interesting news, articles, interviews and videos: Apple plugs zero-day holes used in targeted iPhone attacks (CVE-2025-31200, CVE-2025-31201) Apple has released emergency security updates for iOS/iPadOS, macOS, …',
#   'url': 'https://www.helpnetsecurity.com/2025/04/20/week-in-review-llm-package-hallucinations-harm-supply-chains-nagios-log-server-flaws-fixed/',
#   'urlToImage': 'https://img.helpnetsecurity.com/wp-content/uploads/2024/03/25124834/cybersecurity-week-review-3-1500.webp',
#   'publishedAt': '2025-04-20T08:00:17Z',
#   'content': 'Heres an overview of some of last weeks most interesting news, articles, interviews and videos:\r\nApple plugs zero-day holes used in targeted iPhone attacks (CVE-2025-31200, CVE-2025-31201)Apple has r… [+7222 chars]'},
#  {'source': {'id': None, 'name': 'The Root'},
#   'author': 'The Root Bot',
#   'title': 'Weekend Entertainment Roundup April 19, 2025',
#   'description': 'Photo: Neilson Barnard (Getty Images), YouTube/Jennifer Hudson Show, Noam Galai (Getty Images), Kevin Winter (Getty Images), Instagram, Arturo Holmes (Getty Images), Leon Bennett for ESSENCE (Getty Images), Maya Dehlin Spach (Getty Images), Lauren DeCicca (Ge…',
#   'url': 'https://www.theroot.com/weekend-entertainment-roundup-april-19-2025-1851776815',
#   'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/bea347a083ad6b5f2c8925aa14d59614.jpg',
#   'publishedAt': '2025-04-19T13:00:00Z',
#   'content': 'In a world where social media has become the town square and fans expect their faves to be tapped into the culture, its become increasingly easy to spot when a celebrity misses the mark. Whether its … [+364 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'multivac@sunholo.com',
#   'title': 'sunholo 0.132.0',
#   'description': 'AI DevOps - a package to help deploy GenAI to the Cloud.',
#   'url': 'https://pypi.org/project/sunholo/0.132.0/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-21T12:42:07Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'multivac@sunholo.com',
#   'title': 'sunholo 0.131.4',
#   'description': 'AI DevOps - a package to help deploy GenAI to the Cloud.',
#   'url': 'https://pypi.org/project/sunholo/0.131.4/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-19T19:29:15Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'multivac@sunholo.com',
#   'title': 'sunholo 0.131.7',
#   'description': 'AI DevOps - a package to help deploy GenAI to the Cloud.',
#   'url': 'https://pypi.org/project/sunholo/0.131.7/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-20T14:08:51Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'hello@lunary.ai',
#   'title': 'lunary 1.4.11',
#   'description': 'Python SDK for Lunary, the open-source platform where GenAI teams manage and improve LLM chatbots.',
#   'url': 'https://pypi.org/project/lunary/1.4.11/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-15T10:17:28Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'multivac@sunholo.com',
#   'title': 'sunholo 0.131.6',
#   'description': 'AI DevOps - a package to help deploy GenAI to the Cloud.',
#   'url': 'https://pypi.org/project/sunholo/0.131.6/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-20T09:27:21Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'multivac@sunholo.com',
#   'title': 'sunholo 0.131.8',
#   'description': 'AI DevOps - a package to help deploy GenAI to the Cloud.',
#   'url': 'https://pypi.org/project/sunholo/0.131.8/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-20T14:26:24Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'john@johnrood.com',
#   'title': 'vector-vault 6.0.9.4',
#   'description': 'Quickly create ChatGPT RAG apps and Unleash the full potential of GenAI with Vector Vault',
#   'url': 'https://pypi.org/project/vector-vault/6.0.9.4/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-20T16:05:38Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'hello@lunary.ai',
#   'title': 'lunary 1.4.10',
#   'description': 'Python SDK for Lunary, the open-source platform where GenAI teams manage and improve LLM chatbots.',
#   'url': 'https://pypi.org/project/lunary/1.4.10/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-15T09:54:18Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'no-reply@futureagi.com',
#   'title': 'futureagi 0.5.9',
#   'description': 'We help GenAI teams maintain high-accuracy for their Models in production.',
#   'url': 'https://pypi.org/project/futureagi/0.5.9/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-16T12:37:06Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'multivac@sunholo.com',
#   'title': 'sunholo 0.131.5',
#   'description': 'AI DevOps - a package to help deploy GenAI to the Cloud.',
#   'url': 'https://pypi.org/project/sunholo/0.131.5/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-20T08:51:00Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'multivac@sunholo.com',
#   'title': 'sunholo 0.131.10',
#   'description': 'AI DevOps - a package to help deploy GenAI to the Cloud.',
#   'url': 'https://pypi.org/project/sunholo/0.131.10/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-20T15:10:47Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Pypi.org'},
#   'author': 'multivac@sunholo.com',
#   'title': 'sunholo 0.131.9',
#   'description': 'AI DevOps - a package to help deploy GenAI to the Cloud.',
#   'url': 'https://pypi.org/project/sunholo/0.131.9/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-20T14:38:23Z',
#   'content': 'A required part of this site couldnt load. This may be due to a browser\r\n extension, network issues, or browser settings. Please check your\r\n connection, disable any ad blockers, or try using a diffe… [+12 chars]'},
#  {'source': {'id': None, 'name': 'Computerworld'},
#   'author': 'Viktor Eriksson',
#   'title': 'Hello, Flipper! Google has developed a genAI model to talk to dolphins',
#   'description': 'Google has unveiled a new generative AI (genAI) model, Dolphin Gemma, which will attempt to decode how dolphins communicate with each other.\r\n\n\n\n\nDolphins are among the most intelligent animals on the planet and communicate partly through whistles and calls. …',
#   'url': 'https://www.computerworld.com/article/3962959/google-has-developed-ai-model-to-talk-to-dolphins.html',
#   'urlToImage': 'https://www.computerworld.com/wp-content/uploads/2025/04/3962959-0-90597300-1744732678-dolphin-1019615_1280.jpg?quality=50&strip=all&w=1024',
#   'publishedAt': '2025-04-15T15:57:14Z',
#   'content': 'Google has unveiled a new generative AI (genAI) model, Dolphin Gemma, which will attempt to decode how dolphins communicate with each other.\r\nDolphins are among the most intelligent animals on the pl… [+430 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'scmp.com',
#   'title': 'GenAI investment can spur ‘co-working’ potential in financial industry, Moody’s says',
#   'description': 'Moody’s has developed 35 AI-driven agents with specific instructions, personalities and access to data and research to perform different tasks.',
#   'url': 'https://biztoc.com/x/a83d8069e26d838b',
#   'urlToImage': 'https://biztoc.com/cdn/a83d8069e26d838b_s.webp',
#   'publishedAt': '2025-04-21T03:34:59Z',
#   'content': 'Moodys has developed 35 AI-driven agents with specific instructions, personalities and access to data and research to perform different tasks.\r\nThis story appeared on scmp.com, 2025-04-21 03:30:12.'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'benzinga.com',
#   'title': 'Google GenAI, AI Cloud Services Drive Analyst Confidence In Long-Term Growth',
#   'description': 'Over the next three to five years, Google’s primary upside valuation driver will be its proprietary large language models (LLMs). \nThat’s according to Needham analyst Laura Martin, who reiterated Alphabet Inc. (NASDAQ:GOOGL), Google’s parent company, with a B…',
#   'url': 'https://biztoc.com/x/8108879756c83fbc',
#   'urlToImage': 'https://biztoc.com/cdn/8108879756c83fbc_s.webp',
#   'publishedAt': '2025-04-16T18:10:43Z',
#   'content': 'Over the next three to five years, Googles primary upside valuation driver will be its proprietary large language models (LLMs). Thats according to Needham analyst Laura Martin, who reiterated Alphab… [+143 chars]'},
#  {'source': {'id': None, 'name': 'pymnts.com'},
#   'author': 'PYMNTS',
#   'title': 'Report: Anthropic Set to Add Voice Capabilities to AI Assistant Claude',
#   'description': 'Anthropic is reportedly set to add voice capabilities to its artificial intelligence (AI) assistant, Claude. The new “voice mode” could be released this month and will first be available on a limited basis, Bloomberg reported Tuesday (April 15), citing an unn…',
#   'url': 'https://www.pymnts.com/artificial-intelligence-2/2025/report-anthropic-set-to-add-voice-capabilities-to-ai-assistant-claude/',
#   'urlToImage': 'https://www.pymnts.com/wp-content/uploads/2025/04/Anthropic-voice-Claude.jpg',
#   'publishedAt': '2025-04-16T00:14:47Z',
#   'content': 'Anthropic is reportedly set to add voice capabilities to its artificial intelligence (AI) assistant, Claude.\r\nThe new voice mode could be released this month and will first be available on a limited … [+2269 chars]'},
#  {'source': {'id': None, 'name': 'Cisco.com'},
#   'author': 'Katie Evans',
#   'title': 'Why SMBs Put Security First When Powering Up Their Technology Stacks',
#   'description': 'SMBs are prioritizing AI and security investments to boost efficiency and ensure protection while adapting to remote work and competitive market demands.',
#   'url': 'https://blogs.cisco.com/partner/why-smbs-put-security-first-when-powering-up-their-technology-stacks',
#   'urlToImage': 'https://storage.googleapis.com/blogs-images-new/ciscoblogs/1/2025/04/AdobeStock_555641684.jpeg',
#   'publishedAt': '2025-04-17T15:00:29Z',
#   'content': 'SMBs are embracing advancements in technology to achieve more with a leaner staff, enable remote work, automate manual processes, and reduce errors. When implemented thoughtfully, technology can help… [+4524 chars]'},
#  {'source': {'id': None, 'name': 'Elastic.co'},
#   'author': 'Miguel Luna,Akhilesh Pokhariyal,Trevor Blackford,Daniela Tzvetkova,Chris Munns',
#   'title': 'Elastic Observability 9.0/8.18: Elastic Distributions of OpenTelemetry (EDOT) now GA, LLM observability, and more',
#   'description': 'Elastic Observability 8.18/9.0 announces the GA of Elastic Distributions of OpenTelemetry (EDOT) and LLM observability for OpenAI, Azure OpenAI, AWS Bedrock, and Google Vertex AI....',
#   'url': 'https://www.elastic.co/blog/whats-new-elastic-observability-9-0-0',
#   'urlToImage': 'https://static-www.elastic.co/v3/assets/bltefdd0b53724fa2ce/blt0af137287f550a4a/67f086e2b509b7545030a535/blog-observability-release-blog.png',
#   'publishedAt': '2025-04-15T00:00:00Z',
#   'content': 'Elastic Observability 9.0/8.18 announces several key capabilities:\r\n<ul><li>General availability of Elastic Distributions of OpenTelemetry (EDOT): All EDOT components (including the EDOT Collector an… [+8976 chars]'},
#  {'source': {'id': None,
#    'name': 'Harvard School of Engineering and Applied Sciences'},
#   'author': 'jweaver',
#   'title': 'ASML Fellow Launches CLR:SKY',
#   'description': "I am grateful to have been part of the first cohort of fellows at the Applied Social Media Lab at Harvard's Berkman Klein Center for Internet and Society. Over the past six months, my fellowship has focused on finding practical ways to reduce online polarizat…",
#   'url': 'https://cyber.harvard.edu/story/2025-04/asml-fellow-launches-clrsky',
#   'urlToImage': 'https://cyber.harvard.edu/sites/default/files/styles/image_large/public/2025-04/Copy%20of%20Cyber%20template.png.webp?itok=2l_HjV1Y',
#   'publishedAt': '2025-04-15T18:49:08Z',
#   'content': "I am grateful to have been part of the first cohort of fellows at the Applied Social Media Lab at Harvard's Berkman Klein Center for Internet and Society. Over the past six months, my fellowship has … [+5756 chars]"},
#  {'source': {'id': None,
#    'name': 'Harvard School of Engineering and Applied Sciences'},
#   'author': 'jweaver',
#   'title': 'CLR:SKY Launches, A New AI-Powered Civility Overlay for Bluesky',
#   'description': "I am grateful to have been part of the first cohort of fellows at the Applied Social Media Lab at Harvard's Berkman Klein Center for Internet and Society. Over the past six months, my fellowship has focused on finding practical ways to reduce online polarizat…",
#   'url': 'https://cyber.harvard.edu/story/2025-04/clrsky-launches-new-ai-powered-civility-overlay-bluesky',
#   'urlToImage': 'https://cyber.harvard.edu/sites/default/files/styles/image_large/public/2025-04/Copy%20of%20Cyber%20template.png.webp?itok=2l_HjV1Y',
#   'publishedAt': '2025-04-15T18:49:08Z',
#   'content': "I am grateful to have been part of the first cohort of fellows at the Applied Social Media Lab at Harvard's Berkman Klein Center for Internet and Society. Over the past six months, my fellowship has … [+5753 chars]"},
#  {'source': {'id': None, 'name': 'GlobeNewswire'},
#   'author': 'Interview Kickstart',
#   'title': 'Applied Generative AI Course Launched by Interview Kickstart - 2025 Best GenAI Course With Agentic AI Projects For Top AI Jobs at Google Meta Netflix Microsoft OpenAI Nvidia',
#   'description': 'Santa Clara, April  17, 2025  (GLOBE NEWSWIRE) -- Santa Clara, California -    Following the recent announcement that Chinese technology giant Baidu...',
#   'url': 'https://www.globenewswire.com/news-release/2025/04/17/3063915/0/en/Applied-Generative-AI-Course-Launched-by-Interview-Kickstart-2025-Best-GenAI-Course-With-Agentic-AI-Projects-For-Top-AI-Jobs-at-Google-Meta-Netflix-Microsoft-OpenAI-Nvidia.html',
#   'urlToImage': None,
#   'publishedAt': '2025-04-17T23:14:00Z',
#   'content': 'Santa Clara, April 17, 2025 (GLOBE NEWSWIRE) -- Santa Clara, California - \r\nFollowing the recent announcement that Chinese technology giant Baidu has released two new artificial intelligence models, … [+5073 chars]'},
#  {'source': {'id': None, 'name': 'GlobeNewswire'},
#   'author': 'Interview Kickstart',
#   'title': 'AI Agents for Ecommerce - Interview Kickstart Agentic AI and Generative AI Course 2025',
#   'description': "Santa Clara, April  15, 2025  (GLOBE NEWSWIRE) -- Santa Clara, California -    Agentic AI is not just a buzzword anymore, it's transforming how...",
#   'url': 'https://www.globenewswire.com/news-release/2025/04/15/3062001/0/en/AI-Agents-for-Ecommerce-Interview-Kickstart-Agentic-AI-and-Generative-AI-Course-2025.html',
#   'urlToImage': None,
#   'publishedAt': '2025-04-15T16:42:00Z',
#   'content': "Santa Clara, April 15, 2025 (GLOBE NEWSWIRE) -- Santa Clara, California - \r\nAgentic AI is not just a buzzword anymore, it's transforming how businesses operate. These intelligent systems can make dec… [+5600 chars]"},
#  {'source': {'id': None, 'name': 'BusinessLine'},
#   'author': 'Vallari Sanzgiri',
#   'title': 'TCS to collaborate with Vianai for real-time business insights with conversational AI',
#   'description': 'Tata Consultancy Services (TCS) on Thursday announced a partnership with Vianai Systems, an enterprise-grade, domain-specific generative AI applications provider, to leverage its hila platform for customers, enabling them to engage in conversations with their…',
#   'url': 'https://www.thehindubusinessline.com/info-tech/tcs-to-collaborate-with-vianai-for-real-time-business-insights-with-conversational-ai/article69460586.ece',
#   'urlToImage': 'https://bl-i.thgim.com/public/incoming/17pk1i/article69460825.ece/alternates/LANDSCAPE_1200/2025-04-11T220810Z_1248915980_RC21P1AV5GKT_RTRMADP_3_TECH-AI-THINKINGMACHINES.JPG',
#   'publishedAt': '2025-04-17T12:38:56Z',
#   'content': 'Tata Consultancy Services (TCS) on Thursday announced a partnership with Vianai Systems, an enterprise-grade, domain-specific generative AI applications provider, to leverage its hila platform for cu… [+1405 chars]'},
#  {'source': {'id': None, 'name': 'Mongodb.com'},
#   'author': 'Benjamin Lorenz',
#   'title': 'Transforming News Into Audio Experiences with MongoDB and AI',
#   'description': "You wake up, brew your coffee, and start your day with a perfectly tailored podcast summarizing the latest news—delivered in a natural, engaging voice. No manual curation, no human narration, just seamless AI magic. Sounds like the future? It's happening now,…",
#   'url': 'https://mongodb.com/blog/post/transforming-news-into-audio-experiences-mongodb-ai',
#   'urlToImage': 'https://webassets.mongodb.com/_com_assets/cms/Meta Image Template (14)-yzop0t9kl8.png',
#   'publishedAt': '2025-04-21T15:00:00Z',
#   'content': 'You wake up, brew your coffee, and start your day with a perfectly tailored podcast summarizing the latest newsdelivered in a natural, engaging voice. No manual curation, no human narration, just sea… [+5849 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'investors.com',
#   'title': 'Inside Palantir AI Strategy: How Forward Deployed Engineers Make A Difference',
#   'description': 'Palantir Technologies (PLTR), just like many software companies, is under the gun to show investors the money — a revenue lift from generative artificial intelligence (genAI) products and services. Palantir stock has outperformed most software peers in 2025 a…',
#   'url': 'https://biztoc.com/x/ce015e05207f86e0',
#   'urlToImage': 'https://biztoc.com/cdn/ce015e05207f86e0_s.webp',
#   'publishedAt': '2025-04-17T12:26:21Z',
#   'content': 'Palantir Technologies (PLTR), just like many software companies, is under the gun to show investors the money a revenue lift from generative artificial intelligence (genAI) products and services. Pal… [+146 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'pymnts.com',
#   'title': 'How CFOs Are Unlocking the Power of Advanced Analytics',
#   'description': 'Some opportunities are too great to ignore. For chief financial officers looking to give their procurement processes a shot in the arm, generative artificial intelligence (GenAI) represents one of those opportunities.\nAccording to the latest numbers from the …',
#   'url': 'https://biztoc.com/x/c3970f7351e7dabb',
#   'urlToImage': 'https://biztoc.com/cdn/930/og.png',
#   'publishedAt': '2025-04-16T08:46:19Z',
#   'content': 'Some opportunities are too great to ignore. For chief financial officers looking to give their procurement processes a shot in the arm, generative artificial intelligence (GenAI) represents one of th… [+140 chars]'},
#  {'source': {'id': None, 'name': 'pymnts.com'},
#   'author': 'PYMNTS',
#   'title': 'Perplexity Reportedly Planning AI Partnerships With Samsung and Motorola',
#   'description': 'AI startup\xa0Perplexity\xa0is reportedly working to integrate its technology with\xa0Samsung\xa0and\xa0Motorola\xa0smartphones. The company is in talks with Samsung about adding its artificial intelligence (AI) assistants to that firm’s devices, and has reached an agreement f…',
#   'url': 'https://www.pymnts.com/artificial-intelligence-2/2025/perplexity-reportedly-planning-ai-partnerships-with-samsung-and-motorola/',
#   'urlToImage': 'https://www.pymnts.com/wp-content/uploads/2024/05/Perplexity.jpg',
#   'publishedAt': '2025-04-17T12:55:39Z',
#   'content': 'AI startup\xa0Perplexity\xa0is reportedly working to integrate its technology with\xa0Samsung\xa0and\xa0Motorola\xa0smartphones.\r\nThe company is in talks with Samsung about adding its artificial intelligence (AI) assi… [+2714 chars]'},
#  {'source': {'id': None, 'name': 'SiliconANGLE News'},
#   'author': 'Paul Gillin',
#   'title': 'Certinia enhances AI features across its services delivery software',
#   'description': 'Certinia Inc., the developer of services delivery software based on the Salesforce Inc. platform, today released a series of new and updated features aimed at improving service delivery, project management and customer success through expanded artificial inte…',
#   'url': 'https://siliconangle.com/2025/04/16/certinia-enhances-ai-features-across-services-delivery-software/',
#   'urlToImage': 'https://d15shllkswkct0.cloudfront.net/wp-content/blogs.dir/1/files/2024/10/1passwordtdsyneex.png',
#   'publishedAt': '2025-04-16T12:00:17Z',
#   'content': 'Certinia Inc., the developer of services delivery software based on the Salesforce Inc. platform, today released a series of new and updated features aimed at improving service delivery, project mana… [+4971 chars]'},
#  {'source': {'id': None, 'name': 'pymnts.com'},
#   'author': 'PYMNTS',
#   'title': 'Corvic Raises $12 Million for Technology That Produces ‘AI-Ready Data’',
#   'description': 'Corvic AI has raised $12 million in seed funding and unveiled its artificial intelligence (AI) cognitive infrastructure that transforms raw proprietary enterprise data into actionable intelligence. This solution is designed to overcome the challenges enterpri…',
#   'url': 'https://www.pymnts.com/artificial-intelligence-2/2025/corvic-raises-12-million-for-technology-that-produces-ai-ready-data/',
#   'urlToImage': 'https://www.pymnts.com/wp-content/uploads/2025/04/Corvic-AI-database.jpg',
#   'publishedAt': '2025-04-16T19:49:26Z',
#   'content': 'Corvic AI has raised $12 million in seed funding and unveiled its artificial intelligence (AI) cognitive infrastructure that transforms raw proprietary enterprise data into actionable intelligence.\r\n… [+2530 chars]'},
#  {'source': {'id': None, 'name': 'BusinessLine'},
#   'author': 'Sanjana B',
#   'title': 'India’s GCC market projected to grow to $99–105 billion, highlights report',
#   'description': "India's GCC market set to reach $99-105 billion with 2.4 million professionals, focusing on Tier-2 cities and emerging tech roles.",
#   'url': 'https://www.thehindubusinessline.com/news/indias-gcc-market-projected-to-grow-to-99105-billion-highlights-report/article69453482.ece',
#   'urlToImage': 'https://bl-i.thgim.com/public/incoming/b817bk/article69453953.ece/alternates/LANDSCAPE_1200/IMG_iStock-1210738795_2_1_BLA5F4VJ.jpg',
#   'publishedAt': '2025-04-15T16:22:24Z',
#   'content': 'Indias GCC market is expected to grow to $99105 billion with over 2.4 million professionals in the workforce, according to a report by Quess IT Staffing. \r\nThe Indias GCC Tech Talent Landscape 2024 R… [+1654 chars]'},
#  {'source': {'id': None, 'name': 'ETF Daily News'},
#   'author': 'MarketBeat News',
#   'title': 'Nebius Group (NBIS) Projected to Post Quarterly Earnings on Friday',
#   'description': 'Nebius Group (NASDAQ:NBIS – Get Free Report) will likely be announcing its earnings results before the market opens on Friday, April 25th. Analysts expect Nebius Group to post earnings of ($0.41) per share and revenue of $61.55 million for the quarter. Nebius…',
#   'url': 'https://www.etfdailynews.com/2025/04/18/nebius-group-nbis-projected-to-post-quarterly-earnings-on-friday/',
#   'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/nebius-group-nv-logo-1200x675.jpg?v=20240923132120&w=240&h=240&zc=2',
#   'publishedAt': '2025-04-18T05:14:52Z',
#   'content': 'Nebius Group (NASDAQ:NBIS – Get Free Report) will likely be announcing its earnings results before the market opens on Friday, April 25th. Analysts expect Nebius Group to post earnings of ($0.41) per… [+1816 chars]'},
#  {'source': {'id': None, 'name': 'Unsplash.com'},
#   'author': 'Karen Bradford',
#   'title': 'How AI Is Changing the Way Developers Write Code',
#   'description': 'Remember when GitHub’s CoPilot first made waves by automatically generating source code in 2021? It all seemed like a great way to streamline the process until CCS researchers found that 40% of the code generated was highly vulnerable as it included design fl…',
#   'url': 'https://unsplash.com/photos/a-computer-on-a-desk-FQ3lFA4Zi58',
#   'urlToImage': 'https://dz2cdn1.dzone.com/storage/article-thumb/18339811-thumb.jpg',
#   'publishedAt': '2025-04-16T19:00:09Z',
#   'content': 'Remember when GitHubs CoPilot first made waves by automatically generating source code in 2021? It all seemed like a great way to streamline the process until CCS researchers found that 40% of the co… [+7397 chars]'},
#  {'source': {'id': None, 'name': 'Freerepublic.com'},
#   'author': 'James G. Martin Center for Academic Renewal',
#   'title': 'GenAI Will Not Make Students Smarter',
#   'description': 'By now, most North Carolinians are at least somewhat familiar with Generative AI (GenAI). As tech journalist George Lawton explains, GenAI “uses sophisticated algorithms to organize large, complex data sets into meaningful clusters of information in order to …',
#   'url': 'https://freerepublic.com/focus/f-bloggers/4312286/posts',
#   'urlToImage': None,
#   'publishedAt': '2025-04-21T12:06:41Z',
#   'content': 'Skip to comments.\r\nGenAI Will Not Make Students SmarterJames G. Martin Center for Academic Renewal ^\r\n | April 21, 2025\r\n | David C. Phillips\r\nPosted on 04/21/2025 5:06:41 AM PDT by karpov\r\nBy now, m… [+2674 chars]'},
#  {'source': {'id': None, 'name': 'pymnts.com'},
#   'author': 'PYMNTS',
#   'title': 'How to Manage Risks When Employees Use AI Secretly for Work',
#   'description': 'Employees who use generative artificial intelligence tools in the workplace without company approval or oversight — a practice known as “bring your own AI’ or BYOAI — could introduce risks into the enterprise, according to MIT researchers. “Make no mistake, I…',
#   'url': 'https://www.pymnts.com/news/artificial-intelligence/2025/how-to-manage-risks-when-employees-use-ai-secretly-work/',
#   'urlToImage': 'https://www.pymnts.com/wp-content/uploads/2025/04/Bring-Your-Own-AI.jpg',
#   'publishedAt': '2025-04-17T13:00:26Z',
#   'content': 'Highlights \r\nMIT research shows that many employees are using generative AI tools without company approval, creating security and compliance risks that organizations cant afford to ignore. \r\nThere ar… [+6222 chars]'},
#  {'source': {'id': None, 'name': 'GlobeNewswire'},
#   'author': 'HRB Tax Group, Inc.',
#   'title': 'H&R Block Leverages OpenAI to Create a Force Multiplier for Its Human Expertise',
#   'description': 'Joint initiative merges world-class tax expertise with advanced AI capabilities to enhance real-time assistance for 60,000 tax pros to support millions of taxpayers Joint initiative merges world-class tax expertise with advanced AI capabilities to enhance rea…',
#   'url': 'https://www.globenewswire.com/news-release/2025/04/15/3062009/0/en/H-R-Block-Leverages-OpenAI-to-Create-a-Force-Multiplier-for-Its-Human-Expertise.html',
#   'urlToImage': 'https://ml.globenewswire.com/Resource/Download/2e02de28-a0d3-4f68-b230-236d79fa5d32',
#   'publishedAt': '2025-04-15T17:00:00Z',
#   'content': 'KANSAS CITY, Mo., April 15, 2025 (GLOBE NEWSWIRE) -- H&amp;R Block (NYSE: HRB) and OpenAI today announced a joint effort to develop a generative artificial intelligence (GenAI) solution enabling H&am… [+3541 chars]'},
#  {'source': {'id': None, 'name': 'ETF Daily News'},
#   'author': 'MarketBeat News',
#   'title': 'Nebius Group (NASDAQ:NBIS) Stock Price Down 4.5% on Analyst Downgrade',
#   'description': 'Nebius Group N.V. (NASDAQ:NBIS – Get Free Report) shares dropped 4.5% on Monday after DA Davidson lowered their price target on the stock from $50.00 to $30.00. DA Davidson currently has a buy rating on the stock. Nebius Group traded as low as $20.54 and last…',
#   'url': 'https://www.etfdailynews.com/2025/04/16/nebius-group-nasdaqnbis-stock-price-down-4-5-on-analyst-downgrade/',
#   'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/nebius-group-nv-logo-1200x675.jpg?v=20240923132120&w=240&h=240&zc=2',
#   'publishedAt': '2025-04-16T05:22:57Z',
#   'content': 'Nebius Group N.V. (NASDAQ:NBIS – Get Free Report) shares dropped 4.5% on Monday after DA Davidson lowered their price target on the stock from $50.00 to $30.00. DA Davidson currently has a buy rating… [+2425 chars]'},
#  {'source': {'id': None, 'name': 'ETF Daily News'},
#   'author': 'MarketBeat News',
#   'title': 'DA Davidson Issues Pessimistic Forecast for Nebius Group (NASDAQ:NBIS) Stock Price',
#   'description': 'Nebius Group (NASDAQ:NBIS – Free Report) had its price objective lowered by DA Davidson from $50.00 to $30.00 in a report released on Monday morning,Benzinga reports. The brokerage currently has a buy rating on the stock. Separately, BWS Financial reaffirmed …',
#   'url': 'https://www.etfdailynews.com/2025/04/15/da-davidson-issues-pessimistic-forecast-for-nebius-group-nasdaqnbis-stock-price/',
#   'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/nebius-group-nv-logo.jpg?v=20240923132120&w=240&h=240&zc=2',
#   'publishedAt': '2025-04-15T06:50:47Z',
#   'content': 'Nebius Group (NASDAQ:NBIS – Free Report) had its price objective lowered by DA Davidson from $50.00 to $30.00 in a report released on Monday morning,Benzinga reports. The brokerage currently has a bu… [+2310 chars]'},
#  {'source': {'id': None, 'name': 'pymnts.com'},
#   'author': 'PYMNTS',
#   'title': 'Johnson & Johnson: 15% of AI Use Cases Deliver 80% of Value',
#   'description': 'Johnson & Johnson reportedly found that 10% to 15% of artificial intelligence use cases deliver 80% of the value. The medicine and MedTech company determined that after encouraging employees to experiment with AI and, after about three years, seeing the resul…',
#   'url': 'https://www.pymnts.com/news/artificial-intelligence/2025/johnson-15percent-ai-use-cases-deliver-80percent-value/',
#   'urlToImage': 'https://www.pymnts.com/wp-content/uploads/2025/04/Johnson-and-Johnson.jpg',
#   'publishedAt': '2025-04-18T14:15:54Z',
#   'content': 'Johnson &amp; Johnson reportedly found that 10% to 15% of artificial intelligence use cases deliver 80% of the value.\r\nThe medicine and MedTech company determined that after encouraging employees to … [+2383 chars]'},
#  {'source': {'id': None, 'name': 'Wonkette.com'},
#   'author': 'Robyn Pennacchia',
#   'title': 'The Unbearable Weirdness Of Barron Trump, AI Slop Christian Music Megastar',
#   'description': 'He has fans!',
#   'url': 'https://www.wonkette.com/p/the-unbearable-weirdness-of-barron',
#   'urlToImage': 'https://substackcdn.com/image/fetch/w_1200,h_600,c_fill,f_jpg,q_auto:good,fl_progressive:steep,g_auto/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Ff9ae083d-84b8-410a-91c4-a4e92b0409c7_2356x1470.png',
#   'publishedAt': '2025-04-16T15:07:30Z',
#   'content': 'Move over, whoever it is that has replaced Justin Bieber and Harry Styles in the hearts and minds of American teens \xa0presidential nepobaby Barron Trump is here to sing your faces off, but in a very w… [+7308 chars]'},
#  {'source': {'id': None, 'name': 'Forrester.com'},
#   'author': 'Max Ball',
#   'title': 'CCaaS Vendors Thrive In A Wild Market',
#   'description': "Forrester's Q2 2025 Contact-Center-As-A-Service Wave is out!",
#   'url': 'https://www.forrester.com/blogs/ccaas-vendors-thrive-in-a-wild-market/',
#   'urlToImage': 'https://go.forrester.com/wp-content/uploads/2022/03/FMK_FORR_GenericSocialImage_220314.jpg',
#   'publishedAt': '2025-04-16T15:09:45Z',
#   'content': 'This is my second CCaaS Wave. To the uninitiated, the familiar set of vendors in this Wave could make it appear almost as if there has not been much change in this market.\xa0\xa0\r\nLooks can be deceiving.\xa0… [+4824 chars]'},
#  {'source': {'id': None, 'name': 'Nextgov'},
#   'author': 'Natalie Alms',
#   'title': 'SSA is rolling out a new chatbot for employees',
#   'description': 'The agency has said that it intends to use technology and AI to make up for workforce cuts.',
#   'url': 'https://www.nextgov.com/artificial-intelligence/2025/04/ssa-rolling-out-new-chatbot-employees/404658/',
#   'urlToImage': 'https://cdn.nextgov.com/media/img/cd/2025/04/17/041725chatbotNG/open-graph.jpg',
#   'publishedAt': '2025-04-17T21:17:00Z',
#   'content': 'The Social Security Administration is introducing a new chatbot for employees powered by generative artificial intelligence, according to an internal email obtained by Nextgov/FCW.\xa0\r\nThis initiative … [+2934 chars]'},
#  {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#   'author': 'Himanshi Lohchab and Beena Parmar',
#   'title': 'GenAI will aid margins despite cannibalisation of productivity gains: TCS CFO',
#   'description': 'Samir Seksaria, the chief financial officer at Tata Consultancy Services (TCS), said that while generative AI (genAI) may cannibalise revenues, it enhances productivity, allowing IT firms to deliver the same output with fewer people. He described it as a “win…',
#   'url': 'https://economictimes.indiatimes.com/tech/information-tech/genai-will-aid-margins-despite-cannibalisation-of-productivity-gains-tcs-cfo/articleshow/120289033.cms',
#   'urlToImage': 'https://img.etimg.com/thumb/msid-120289892,width-1200,height-630,imgsize-59396,overlay-ettech/articleshow.jpg',
#   'publishedAt': '2025-04-15T00:30:00Z',
#   'content': 'Artificial intelligence can bring in productivity gains for both IT companies and their customers as they could get the same work done with fewer people at a reduced cost, a top executive at Tata Con… [+3296 chars]'},
#  {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#   'author': 'ETtech',
#   'title': 'TCS, Vishal Sikka’s Vianai Systems tie up to bring GenAI tools to boardrooms',
#   'description': 'The partnership will see Vianai’s ‘hila’ platform – a GenAI system designed to let senior executives like CFOs and CIOs interact with business data in simple English – simplify decision-making by eliminating the need for technical expertise to access or inter…',
#   'url': 'https://economictimes.indiatimes.com/tech/information-tech/tcs-vishal-sikkas-vianai-systems-tie-up-to-bring-genai-tools-to-boardrooms/articleshow/120384321.cms',
#   'urlToImage': 'https://img.etimg.com/thumb/msid-120384316,width-1200,height-630,imgsize-41629,overlay-ettech/articleshow.jpg',
#   'publishedAt': '2025-04-17T14:23:13Z',
#   'content': 'Software services leader Tata Consultancy Services (TCS) has teamed up with former Infosys CEO Vishal Sikka founded Vianai Systems, to bring conversational artificial intelligence (AI) tools to enter… [+2069 chars]'},
#  {'source': {'id': None, 'name': 'pymnts.com'},
#   'author': 'PYMNTS',
#   'title': 'Napster Owner Infinite Reality Valued at $15 Billion After Acquiring Touchcast',
#   'description': 'Metaverse company\xa0Infinite Reality\xa0has been valued at $15.5 billion after purchasing AI firm\xa0Touchcast, the company announced Wednesday (April 16). In purchasing Touchcast, Infinite Reality gets access to products that include artificial intelligence (AI) age…',
#   'url': 'https://www.pymnts.com/acquisitions/2025/napster-owner-infinite-reality-valued-at-15-billion-after-acquiring-touchcast/',
#   'urlToImage': 'https://www.pymnts.com/wp-content/uploads/2025/04/Infinite-Reality-Touchcast.png',
#   'publishedAt': '2025-04-16T14:54:41Z',
#   'content': 'Metaverse company\xa0Infinite Reality\xa0has been valued at $15.5 billion after purchasing AI firm\xa0Touchcast, the company announced Wednesday (April 16).\r\nIn purchasing Touchcast, Infinite Reality gets acc… [+2925 chars]'},
#  {'source': {'id': None, 'name': 'BusinessLine'},
#   'author': 'Sanjana B',
#   'title': 'India’s GCC market projected to grow to $99–105 billion, highlights report',
#   'description': "India's GCC market set to reach $99-105 billion with 2.4 million professionals, focusing on Tier-2 cities and emerging tech roles.",
#   'url': 'https://www.thehindubusinessline.com/economy/indias-gcc-market-projected-to-grow-to-99105-billion-highlights-report/article69453482.ece',
#   'urlToImage': 'https://bl-i.thgim.com/public/incoming/b817bk/article69453953.ece/alternates/LANDSCAPE_1200/IMG_iStock-1210738795_2_1_BLA5F4VJ.jpg',
#   'publishedAt': '2025-04-15T16:22:24Z',
#   'content': 'Indias GCC market is expected to grow to $99105 billion with over 2.4 million professionals in the workforce, according to a report by Quess IT Staffing. \r\nThe Indias GCC Tech Talent Landscape 2024 R… [+1654 chars]'},
#  {'source': {'id': None, 'name': 'Elastic.co'},
#   'author': 'Kelly Manrique',
#   'title': 'The power of a single view: Unifying security and observability in banking',
#   'description': "Banks can't afford downtime or blind spots. Learn how leaders like Wells Fargo and Bank Leumi use Elastic to unify observability and security, improving threat detection, remediation, and system resil...",
#   'url': 'https://www.elastic.co/blog/unifying-security-observability-banking',
#   'urlToImage': 'https://static-www.elastic.co/v3/assets/bltefdd0b53724fa2ce/blt14c0ad5683433dbd/67fffeb40bdcf12b2f5f8015/177920-elastic-blogheader-4.jpg',
#   'publishedAt': '2025-04-16T00:00:00Z',
#   'content': 'Operational resilience requires more than monitoring or defense alone. Banks are combining observability and security to reduce risk, costs, and downtime, without missing a beat.\r\nEvery minute a bank… [+4463 chars]'},
#  {'source': {'id': None, 'name': 'Martech.zone'},
#   'author': 'Douglas Karr',
#   'title': 'ReviewInc: The All-in-One Reputation and Visibility Platform for Service Brands and Multi-Location Businesses',
#   'description': 'Today’s buyers don’t just trust online reviews—they rely on them. Whether it’s a patient choosing a new clinic, a customer looking for a reputable HVAC technician, or a parent evaluating a childcare provider, the verdict is almost always rendered before a sin…',
#   'url': 'https://martech.zone/reviewinc-reputation-review-listings-management/',
#   'urlToImage': 'https://cdn.martech.zone/wp-content/uploads/2025/04/reviewinc-listings-reviews-reputation-management.png',
#   'publishedAt': '2025-04-18T14:59:00Z',
#   'content': 'Todays buyers dont just trust online reviewsthey rely on them. Whether its a patient choosing a new clinic, a customer looking for a reputable HVAC technician, or a parent evaluating a childcare prov… [+5037 chars]'},
#  {'source': {'id': None, 'name': 'NDTV News'},
#   'author': 'NDTV Auto Desk',
#   'title': 'Nissan To Introduce Next-Gen Autonomous Driving Tech By FY27',
#   'description': 'Nissan&#039;s autonomous driving technology uses LiDAR and cameras to be aware of the surroundings.',
#   'url': 'https://www.ndtv.com/auto/nissan-to-introduce-next-gen-autonomous-driving-tech-by-fy27-8177396',
#   'urlToImage': 'https://c.ndtvimg.com/2025-04/3mh9ubco_nissan-autonomous-driving-tech_625x300_16_April_25.jpg?im=FeatureCrop,algorithm=dnn,width=1200,height=800',
#   'publishedAt': '2025-04-16T08:36:35Z',
#   'content': 'Nissan has announced that the brand will soon launch its next-generation autonomous driving technology in the fiscal year 2027. The brand is calling this tech ProPilot technology. It features the bra… [+1433 chars]'},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Carly Quellman',
#   'title': "I Paid for a MasterClass in AI and It's Been Worth Every Penny",
#   'description': "Here's what I learned from a 90-minute video series that helped me use generative AI for work and everyday life.",
#   'url': 'https://www.cnet.com/tech/services-and-software/i-paid-for-a-masterclass-in-ai-and-its-been-worth-every-penny/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/525bf7eb4aba466b4a4276813f75036b9f8b3afc/hub/2024/10/14/30912d0e-b65e-42a6-a561-304e5be83784/gettyimages-2026262347.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2025-04-15T13:00:06Z',
#   'content': "As an eager learner of all things related to\xa0artificial intelligence, I'm always excited to try out any new AI tool or product I come across and provide you with honest feedback about whether it's wo… [+6984 chars]"},
#  {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#   'author': 'IANS',
#   'title': "GenAI's diagnostic capabilities comparable to non-specialist doctors: Study",
#   'description': "A new research on Friday showed that generative AI's (GenAI) diagnostic capabilities are comparable to non-specialist doctors. The average diagnostic accuracy of generative AI was 52.1%, with the latest models of generative AI sometimes showing accuracy on pa…",
#   'url': 'https://economictimes.indiatimes.com/tech/artificial-intelligence/genais-diagnostic-capabilities-comparable-to-non-specialist-doctors-study/articleshow/120408003.cms',
#   'urlToImage': 'https://img.etimg.com/thumb/msid-120408038,width-1200,height-630,imgsize-37322,overlay-ettech/articleshow.jpg',
#   'publishedAt': '2025-04-18T12:11:49Z',
#   'content': "A new research on Friday showed that generative AI's (GenAI) diagnostic capabilities are comparable to non-specialist doctors.The use of generative AI for diagnostics has attracted attention in the m… [+1881 chars]"},
#  {'source': {'id': None, 'name': 'Forrester.com'},
#   'author': 'Allie Mellen',
#   'title': 'Forrester’s Top Threats For 2025',
#   'description': '2025 started with a bang! Technology and geopolitics are changing faster than many can keep track. There’s an announcement of a new, benchmark-shattering generative AI seemingly every week. Planned job cuts across US employers are at their highest levels sinc…',
#   'url': 'https://www.forrester.com/blogs/forresters-top-threats-for-2025/',
#   'urlToImage': 'https://go.forrester.com/wp-content/uploads/2025/04/AM-WP1.jpg',
#   'publishedAt': '2025-04-16T16:13:09Z',
#   'content': '2025 started with a bang! Technology and geopolitics are changing faster than many can keep track. Theres an announcement of a new, benchmark-shattering generative AI seemingly every week. Planned jo… [+2692 chars]'},
#  {'source': {'id': None, 'name': 'Elastic.co'},
#   'author': 'Brian Bergholm',
#   'title': 'Elastic 9.0/8.18: BBQ, EDOT & LLM observability, Attack Discovery, Auto Import, and ES|QL JOIN',
#   'description': 'Elastic 9.0, built on Lucene 10.0, marks a major upgrade for Elasticsearch. Elastic 9.0/8.18 includes faster BBQ, Elastic Distributions of OTel (EDOT) and LLM observability, Attack Discovery, Automati...',
#   'url': 'https://www.elastic.co/blog/whats-new-elastic-9-0-0',
#   'urlToImage': 'https://static-www.elastic.co/v3/assets/bltefdd0b53724fa2ce/blt88a7d7eff8d5daef/67f3474ad32f6859feef2112/combined-blog.png',
#   'publishedAt': '2025-04-15T00:00:00Z',
#   'content': 'Today, we are pleased to announce the general availability of both Elastic 9.0 and 8.18!\r\nIf you thought the 8.x stream of releases was impressive given features like ANN, TSDB, ELSER, ES|QL, LTR, BB… [+6705 chars]'},
#  {'source': {'id': None, 'name': 'Researchbuzz.me'},
#   'author': 'ResearchBuzz',
# ...
#  {'source': {'id': None, 'name': 'VentureBeat'},
#   'author': 'Michael Nuñez',
#   'title': 'Sam Altman at TED 2025: Inside the most uncomfortable — and important — AI interview of the year',
#   'description': 'At TED 2025, OpenAI CEO Sam Altman faced tough questions on AI ethics, artist compensation, and the risks of autonomous agents in a tense interview with TED’s Chris Anderson, revealing new details about OpenAI’s explosive growth and future plans.',
#   'url': 'https://venturebeat.com/ai/sam-altman-at-ted-2025-inside-the-most-uncomfortable-and-important-ai-interview-of-the-year/',
#   'urlToImage': 'https://venturebeat.com/wp-content/uploads/2025/04/TED2025_20250411_2JR4077-medium.jpg?w=1024?w=1200&strip=all',
#   'publishedAt': '2025-04-15T21:17:23Z',
#   'content': 'Join our daily and weekly newsletters for the latest updates and exclusive content on industry-leading AI coverage. Learn More\r\nOpenAI CEO Sam Altman revealed that his company has grown to 800 millio… [+8323 chars]'},
#  {'source': {'id': None, 'name': 'VentureBeat'},
#   'author': 'Shauli Rozen, ARMO',
#   'title': 'The open source advantage: Faster bugs, better builds, wider buy-in',
#   'description': 'Open-sourcing is definitely not something to rush into. Here are some pros, cons and general advice based on experience.',
#   'url': 'https://venturebeat.com/programming-development/the-open-source-advantage-faster-bugs-better-builds-wider-buy-in/',
#   'urlToImage': 'https://venturebeat.com/wp-content/uploads/2025/04/upscalemedia-transformed_fd4bbe.webp?w=1024?w=1200&strip=all',
#   'publishedAt': '2025-04-19T19:05:00Z',
#   'content': 'Join our daily and weekly newsletters for the latest updates and exclusive content on industry-leading AI coverage. Learn More\r\nSoftware companies have a lot of decisions to make as they move through… [+7818 chars]'},
#  {'source': {'id': None, 'name': 'AppleInsider'},
#   'author': 'news@appleinsider.com (Amber Neely)',
#   'title': "How India's emerging filmmakers use iPhone 16 Pro Max",
#   'description': 'Four Indian filmmakers in the MAMI Select: Filmed on iPhone project explain how the iPhone 16 Pro Max has helped them to create their short films.MAMI Select: Filmed on iPhone | Image Credit: AppleThe Mumbai Academy of the Moving Image (MAMI) Select: Shot on …',
#   'url': 'https://appleinsider.com/articles/25/04/15/how-indias-emerging-filmmakers-use-iphone-16-pro-max',
#   'urlToImage': 'https://photos5.appleinsider.com/gallery/63332-131602-indiamovie-xl.jpg',
#   'publishedAt': '2025-04-15T19:31:57Z',
#   'content': 'Four Indian filmmakers in the MAMI Select: Filmed on iPhone project explain how the iPhone 16 Pro Max has helped them to create their short films. \r\nThe Mumbai Academy of the Moving Image (MAMI) Sele… [+2684 chars]'},
#  {'source': {'id': None, 'name': 'AppleInsider'},
#   'author': 'news@appleinsider.com (Charles Martin)',
#   'title': 'Australian shoemaker business has been transformed by iPhone, says Apple',
#   'description': 'Apple has highlighted how an Australian shoe company replaced its traditional point-of-sale machines with iPhones, making for a better customer experience.Using the NewStore app, employees can check inventory instantly — image credit: AppleFirms are regularly…',
#   'url': 'https://appleinsider.com/articles/25/04/19/australian-shoemaker-business-has-been-transformed-by-iphone-says-apple',
#   'urlToImage': 'https://photos5.appleinsider.com/gallery/63364-131673-hero_iphone_inventory__dmhhf4h6kamq_large_2x-xl.jpg',
#   'publishedAt': '2025-04-19T18:18:08Z',
#   'content': 'Apple has highlighted how an Australian shoe company replaced its traditional point-of-sale machines with iPhones, making for a better customer experience.\r\nFirms are regularly spotlighted by Apple i… [+1842 chars]'},
#  {'source': {'id': None, 'name': 'Designboom'},
#   'author': 'ravail khan I designboom',
#   'title': 'UK pavilion’s punched aluminum skin by WOO recalls industrial heritage at expo 2025 osaka',
#   'description': 'the facade, shifting with daylight and revealing a glowing union jack at night, nods to the evolution of early programmable technology in the UK.\nThe post UK pavilion’s punched aluminum skin by WOO recalls industrial heritage at expo 2025 osaka appeared first…',
#   'url': 'https://www.designboom.com/architecture/uk-pavilion-aluminum-woo-industrial-heritage-expo-2025-osaka-es-global-04-15-2025/',
#   'urlToImage': 'https://www.designboom.com/twitterimages/uploads/2025/04/uk-pavilion-expo-2025-osaka-woo-es-global-designboom-1200.jpg',
#   'publishedAt': '2025-04-15T10:00:53Z',
#   'content': 'WOO architects &amp; es global present uk pavilion at expo 2025 osaka\r\nAsExpo 2025 Osaka officially kicks off, the UK Pavilion opens its doors under the theme Come Build the Future — a celebration of… [+3275 chars]'},
#  {'source': {'id': None, 'name': 'Harvard Business Review'},
#   'author': None,
#   'title': 'How Financial Inclusion and Health Can Move More People into the Middle Class - SPONSOR CONTENT FROM MASTERCARD',
#   'description': 'Sponsor content from Mastercard.',
#   'url': 'https://hbr.org/sponsored/2025/04/how-financial-inclusion-and-health-can-move-more-people-into-the-middle-class',
#   'urlToImage': 'https://hbr.org/resources/images/article_assets/2025/04/17BBAB16-DA2C-49EC-8C7D-8728E99F526F.jpeg',
#   'publishedAt': '2025-04-21T16:40:00Z',
#   'content': 'Skip to content\r\nSponsor content from Mastercard.\r\n"&gt;\r\nSponsor content from Mastercard.\r\n"&gt;\r\nBy Shamina Singh and Homi Kharas\r\nMuch ink has been spilled over the damage of inflation, migration,… [+5681 chars]'},
#  {'source': {'id': None, 'name': 'PetaPixel'},
#   'author': 'Jeremy Gray',
#   'title': 'Incredible Photo of a Dying Star Shows How Far Telescopes Have Come',
#   'description': "The James Webb Space Telescope's (JWST) new mid-infrared image of the planetary nebula NGC 1514, which shows a dying heart at its center ejecting vast quantities of gas and dust, is spectacular in itself. It's also an incredible example of how far space teles…",
#   'url': 'https://petapixel.com/2025/04/15/incredible-photo-of-a-dying-star-shows-how-far-telescopes-have-come/',
#   'urlToImage': 'https://petapixel.com/assets/uploads/2025/04/webb-wise-ngc-1514-featured.jpg',
#   'publishedAt': '2025-04-15T19:51:25Z',
#   'content': '‘Two infrared views of NGC 1514. At left is an observation from NASAs Wide-field Infrared Survey Explorer (WISE). At right is a more refined image from NASA’s James Webb Space Telescope.’ | Credits: … [+4924 chars]'},
#  {'source': {'id': None, 'name': 'TalkAndroid'},
#   'author': 'Peter Holden',
#   'title': 'Android Automotive quietly adds always-on dashcam support – here’s what it means',
#   'description': "Android Automotive's native dashcam feature represents a significant evolution in vehicle technology. Google has developed an open-source dashcam application",
#   'url': 'https://www.talkandroid.com/504975-android-automotive-quietly-adds-always-on-dashcam-support-heres-what-it-means/',
#   'urlToImage': 'https://www.talkandroid.com/wp-content/uploads/2025/04/Canva-TalkAndroid-2.png',
#   'publishedAt': '2025-04-17T20:17:41Z',
#   'content': "Android Automotive's native dashcam feature represents a significant evolution in vehicle technology. Google has developed an open-source dashcam application specifically designed for Android Automot… [+4118 chars]"},
#  {'source': {'id': None, 'name': 'TalkAndroid'},
#   'author': 'Talk Android',
#   'title': 'Windows 11 has a secret anti-malware tool — here’s how to turn it on',
#   'description': 'Windows 11 offers numerous security features, yet one of its most powerful protections remains surprisingly underutilized. **Core isolation technology**',
#   'url': 'https://www.talkandroid.com/504999-windows-11-has-a-secret-anti-malware-tool-heres-how-to-turn-it-on/',
#   'urlToImage': 'https://www.talkandroid.com/wp-content/uploads/2025/04/Canva-TalkAndroid-7.png',
#   'publishedAt': '2025-04-20T15:30:00Z',
#   'content': 'Windows 11 offers numerous security features, yet one of its most powerful protections remains surprisingly underutilized. **Core isolation technology** provides robust defense against sophisticated … [+4614 chars]'},
#  {'source': {'id': None, 'name': 'Science Daily'},
#   'author': None,
#   'title': 'Simulating protein structures involved in memory formation',
#   'description': 'Complex protein interactions at synapses are essential for memory formation in our brains, but the mechanisms behind these processes remain poorly understood. Now, researchers have developed a computational model revealing new insights into the unique droplet…',
#   'url': 'https://www.sciencedaily.com/releases/2025/04/250416135614.htm',
#   'urlToImage': 'https://www.sciencedaily.com/images/scidaily-icon.png',
#   'publishedAt': '2025-04-16T17:56:14Z',
#   'content': 'Complex protein interactions at synapses are essential for memory formation in our brains, but the mechanisms behind these processes remain poorly understood. Now, researchers from Japan have develop… [+6897 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'finance.yahoo.com',
#   'title': 'Why Recon Technology (RCON) Is Crashing This Week',
#   'description': 'In This Article:\nWe recently published a list of Energy Stocks that are Losing This Week. In this article, we are going to take a look at where Recon Technology, Ltd. (NASDAQ:RCON) stands against other energy stocks that are crashing this week.\nAfter an encou…',
#   'url': 'https://biztoc.com/x/a2c2f0e981c009b4',
#   'urlToImage': 'https://biztoc.com/cdn/a2c2f0e981c009b4_s.webp',
#   'publishedAt': '2025-04-17T14:05:52Z',
#   'content': 'In This Article:We recently published a list of Energy Stocks that are Losing This Week. In this article, we are going to take a look at where Recon Technology, Ltd. (NASDAQ:RCON) stands against othe… [+150 chars]'},
#  {'source': {'id': None, 'name': 'Yanko Design'},
#   'author': 'Pooja Khanna Tyagi',
#   'title': 'Design In Motion: The Unexpected Ways Kinetic Design is Making Everyday Objects Come Alive',
#   'description': 'Design In Motion: The Unexpected Ways Kinetic Design is Making Everyday Objects Come AliveKinetic designs seem to have a life of their own. They embody emotions and help us view things in a new perspective by integrating fluid...',
#   'url': 'https://www.yankodesign.com/2025/04/16/design-in-motion-the-unexpected-ways-kinetic-design-is-making-everyday-objects-come-alive/',
#   'urlToImage': 'https://www.yankodesign.com/images/design_news/2025/04/design-in-motion-how-kinetic-design-transforms-products/Kinetic-Designs_Motion_Sculpture_5.jpg',
#   'publishedAt': '2025-04-16T08:45:36Z',
#   'content': 'Kinetic designs seem to have a life of their own. They embody emotions and help us view things in a new perspective by integrating fluid movement into products, enabling them to transform in appearan… [+10939 chars]'},
#  {'source': {'id': None, 'name': 'MakeUseOf'},
#   'author': 'Brent Dirks',
#   'title': 'A ChatGPT Social Network Is an Idea We Can All Do Without',
#   'description': "The world doesn't need another social network, even if it has a great image generator.",
#   'url': 'https://www.makeuseof.com/chatgpt-social-network-we-dont-need/',
#   'urlToImage': None,
#   'publishedAt': '2025-04-15T20:01:16Z',
#   'content': 'ChatGPT started the AI chatbot revolution and continues to blaze a trail with the technology. But it would take a big step back if its reported latest idea ever comes to fruition.\r\nDo We Need a ChatG… [+2546 chars]'},
#  {'source': {'id': None, 'name': 'Boredpanda.com'},
#   'author': 'Edvinas Jovaišas',
#   'title': '50 Times People Came Up With Such Amazing DIY Projects, They Had To Share Their Results',
#   'description': 'The world is filled to the brim with incredibly talented individuals. No matter how much time passes and how much technology advances, we can always count on one thing: human beings being drawn to art.',
#   'url': 'https://www.boredpanda.com/open-source-crafting-diy-pics-msn/',
#   'urlToImage': 'https://www.boredpanda.com/blog/wp-content/uploads/2024/03/open-source-crafting-diy-pics-fb-65e59ef0861c7__700-png.jpg',
#   'publishedAt': '2025-04-15T10:00:37Z',
#   'content': 'Article created by: Dominyka\r\nThe world is filled to the brim with incredibly talented individuals. No matter how much time passes and how much technology advances, we can always count on one thing: … [+444 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Expert Panel®, Forbes Councils Member, \n Expert Panel®, Forbes Councils Member\n https://www.forbes.com/councils/forbestechcouncil/people/expertpanel/',
#   'title': '20 Untapped Tech Opportunities To Serve Older Adults',
#   'description': 'Older adults represent a largely underserved demographic in technology.',
#   'url': 'https://www.forbes.com/councils/forbestechcouncil/2025/04/15/20-untapped-tech-opportunities-to-serve-older-adults/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/67fe9ee9b67012cc8733d216/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2025-04-15T18:03:06Z',
#   'content': 'Older Man and Woman Using a Tablet\r\nMarcus Aurelius \r\nOlder adults represent a largely underserved demographic in technology. Despite their increasing adoption of digital tools, most products still c… [+9476 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Alyssa Ochs',
#   'title': "Scientists reach pivotal breakthrough in quest for limitless energy: 'We're not a science project anymore'",
#   'description': 'Proxima Fusion has maintained its position as a global leader in the race to commercial fusion.',
#   'url': 'https://tech.yahoo.com/articles/scientists-reach-pivotal-breakthrough-quest-104532512.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/ZKkjGTxbQtAOFN6OCd.C7A--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03MTE-/https://media.zenfs.com/en/the_cool_down_737/e5d57f220088ed129daafb45e468a35d',
#   'publishedAt': '2025-04-20T10:45:32Z',
#   'content': 'A German startup, Proxima Fusion, has developed a plan to generate limitless energy in a working fusion power plant.\r\nThe plan is a significant development because nuclear fusion creates abundant ene… [+2960 chars]'},
#  {'source': {'id': None, 'name': 'Lawnext.com'},
#   'author': 'Robert Ambrogi',
#   'title': 'The Three Cs Of Teaching Technology To Law Students',
#   'description': 'Are law schools adequately preparing students for the reality that technology is essential to the practice of law?\nUnfortunately, for the majority of law schools, the answer is no.\nThe post The Three Cs Of Teaching Technology To Law Students appeared first on…',
#   'url': 'https://www.lawnext.com/2025/04/the-three-cs-of-teaching-technology-to-law-students.html',
#   'urlToImage': 'https://www.lawnext.com/wp-content/uploads/2025/04/IMG_5534-EDIT.jpg',
#   'publishedAt': '2025-04-18T20:01:00Z',
#   'content': 'In law practice today, technology is no longer optional it’s essential. As practicing attorneys increasingly rely on technology tools to serve clients, conduct research, manage documents and streamli… [+7764 chars]'},
#  {'source': {'id': None, 'name': 'Psychology Today'},
#   'author': 'Jeff Segal Psy.D.',
#   'title': 'Loving From Afar: Grandparenting That Bridges the Distance',
#   'description': 'Mindset, technology, and creative rituals can strengthen bonds and create meaningful grandparent-grandchild connections across miles.',
#   'url': 'https://www.psychologytoday.com/us/blog/bridging-three-generations/202504/loving-from-afar-grandparenting-that-bridges-the-distance',
#   'urlToImage': 'https://cdn2.psychologytoday.com/assets/styles/manual_crop_1_91_1_1528x800/public/teaser_image/blog_entry/2025-04/Blog%20Picture%20Travel%20%20%238-%20onurdongel.jpg?itok=j4XjLR7Z',
#   'publishedAt': '2025-04-17T16:47:11Z',
#   'content': 'While preparing to write my latest post, I came across this banner on a long-distance grandparenting website:\r\n"Grandparenting From Afar:How to Cope With the Grief and Sadness of Long-Distance Grandp… [+5052 chars]'}]
